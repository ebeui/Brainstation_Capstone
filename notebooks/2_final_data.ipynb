# %% [markdown]
# ## Data Preprocessing
#
# **Name**: Diane Lu
#
# **Contact**: dianengalu@gmail.com
#
# **Date**: 07/31/2023

# %% [markdown]
# ## Table of Contents
#
# 1. [Introduction](#intro)
# 2. [Merged Dataset](#merge)
# 3. [Final Dataset](#final)
# 4. [Model Dataset](#model)
# 5. [Vancouver Data](#van)

# %% [markdown]
# ### Introduction <a class="anchor" id="intro"></a>
#
# Data Cleaning is the process of rectifying inconsistencies and handling missing values in raw data to ensure its quality and suitability for analysis and modeling tasks. This essential phase plays a critical role in producing accurate and reliable results from the data-driven processes ahead.

# %% [markdown]
# #### Downloading Yelp Dataset from Kaggle
#
# You can download the necessary Yelp Dataset from [Kaggle](https://www.kaggle.com/datasets/yelp-dataset/yelp-dataset/versions/3?datasetId=10100&sortBy=voteCount&select=Dataset_User_Agreement.pdf). For this data analysis, we will be using Version 3 of the Yelp Dataset found on Kaggle and specifically the business, review, and user datasetS.

# %% [markdown]
# #### Importing Python Libraries
#
# Importing necessary libraries for the Data Preprocessing.

# %%
# Import necessary libraries
import numpy as np 
import pandas as pd 

# Ignore all warnings to avoid cluttering the output
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Merging Datasets for Modeling <a class="anchor" id="merge"></a>

# %%
# Load the pickled business_data DataFrame
business_data = pd.read_pickle('/Users/diane/Desktop/BrainStation/Brainstation_Capstone/yelp_data/business_data.pkl')

# Load the pickled review_data DataFrame
review_data = pd.read_pickle('/Users/diane/Desktop/BrainStation/Brainstation_Capstone/yelp_data/review_data.pkl')

# Load the pickled user_data DataFrame
user_data = pd.read_pickle('/Users/diane/Desktop/BrainStation/Brainstation_Capstone/yelp_data/user_data.pkl')

# %%
# Merge the 'review_data' DataFrame and 'business_data' DataFrame based on the common column 'business_id'
business_reviews = review_data.merge(business_data, on='business_id')

# Display the first few rows of the 'business_reviews' DataFrame
business_reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ
# 1  hpcZLEzqD4_gPi6eSVi_Bg  Y-j2svl0M_5-jF1ehYuNPQ  buF9druCkbuXLX526sGELQ
# 2  3FvY1Se8y2WXqTbaANOqMw  xUCX4GhBpeWxZB0l2lmt_w  buF9druCkbuXLX526sGELQ
# 3  C1uQNP2ehBktS43ZRMEvkg  2M6KFsWIUXElqcQRz4A0Qg  buF9druCkbuXLX526sGELQ
# 4  Cja8_35_kQDnF9g4voikzw  t5SRIRU6INiAyVkiMJhRPA  buF9druCkbuXLX526sGELQ
#
#    stars                                               text restaurant_name  \
# 0    4.0  Apparently Prides Osteria had a rough summer a...  Prides Osteria
# 1    2.0  I was really disappointed to say the least. I ...  Prides Osteria
# 2    5.0  This is as close to dining in Italy as you'll ...  Prides Osteria
# 3    5.0  Great food and service! Again. 4 out of the la...  Prides Osteria
# 4    1.0  We ordered the roasted chicken and homemade pa...  Prides Osteria
#
#           address     city state postal_code   latitude  longitude  \
# 0  240 Rantoul St  Beverly    MA       01915  42.549609 -70.884046
# 1  240 Rantoul St  Beverly    MA       01915  42.549609 -70.884046
# 2  240 Rantoul St  Beverly    MA       01915  42.549609 -70.884046
# 3  240 Rantoul St  Beverly    MA       01915  42.549609 -70.884046
# 4  240 Rantoul St  Beverly    MA       01915  42.549609 -70.884046
#
#    restaurant_rating  restaurant_review_count  is_open  \
# 0                3.5                       83        0
# 1                3.5                       83        0
# 2                3.5                       83        0
# 3                3.5                       83        0
# 4                3.5                       83        0
#
#                                           categories
# 0  [Wine Bars, Nightlife, Farmers Market, Bars, I...
# 1  [Wine Bars, Nightlife, Farmers Market, Bars, I...
# 2  [Wine Bars, Nightlife, Farmers Market, Bars, I...
# 3  [Wine Bars, Nightlife, Farmers Market, Bars, I...
# 4  [Wine Bars, Nightlife, Farmers Market, Bars, I...

# %%
# Merge the 'business_reviews' DataFrame and 'user_data' DataFrame based on the common column 'user_id'
final_business_reviews = business_reviews.merge(user_data, on='user_id')

# Display the first few rows of the 'final_business_reviews' DataFrame
final_business_reviews.head()

# %%
# Pickle the DataFrame
final_business_reviews.to_pickle('/Users/diane/Desktop/BrainStation/Brainstation_Capstone/yelp_data/final_reviews.pkl')

# %% [markdown]
# ### Final Dataset for EDA <a class="anchor" id="final"></a>
#
# **Data Dictionary:**
# * `review_id`: unique review id
# * `user_id`: unique user id
# * `business_id`: unique user id
# * `stars`: star rating
# * `text`: the review itself
# * `restaurant_name`: the restaurant's name
# * `address`: the full address of the restaurant
# * `city`: the city
# * `state`: 2 character state code
# * `postal_code`: the postal code
# * `latitude`: latitude of the restaurant
# * `longitude`: longitude of the restaurant
# * `restaurant_rating`: star rating
# * `restaurant_review_count`: number of reviews
# * `user_review_count`: the number of reviews they've written
# * `is_open`: 0 or 1 for closed or open
# * `categories`: business categories
# * `user_name`: the user's first name
# * `average_stars`: average rating of all reviews

# %%
final_data = pd.read_pickle('/Users/diane/Desktop/BrainStation/Brainstation_Capstone/yelp_data/final_reviews.pkl')

# %%
# Display concise information about the 'final_data' DataFrame
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5574714 entries, 0 to 5574713
# Data columns (total 19 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   review_id                object
#  1   user_id                  object
#  2   business_id              object
#  3   stars                    float64
#  4   text                     object
#  5   restaurant_name          object
#  6   address                  object
#  7   city                     object
#  8   state                    object
#  9   postal_code              object
#  10  latitude                 float64
#  11  longitude                float64
#  12  restaurant_rating        float64
#  13  restaurant_review_count  int64
#  14  is_open                  int64
#  15  categories               object
#  16  name                     object
#  17  user_review_count        int64
#  18  average_stars            float64
# dtypes: float64(5), int64(3), object(11)
# memory usage: 808.1+ MB

# %%
# Display the first few rows of the 'final_data' DataFrame
final_data.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ
# 1  fLlML7BjkR4_fJnND_hEJw  ak0TdVmGKo4pwqdJSTLwWw  bNZ3-0rse12NKdSVqQ30xw
# 2  pRtbswupEVIG1Ykj9xkL7Q  ak0TdVmGKo4pwqdJSTLwWw  BVsIaKL-8QXVjt0Z9WoFWw
# 3  fUYl6bnZy4bSGnbPAizXug  ak0TdVmGKo4pwqdJSTLwWw  4MClvr12OXBNvGu8h1yGpA
# 4  jHh2LIXNsnJCMUiyI9pt5w  ak0TdVmGKo4pwqdJSTLwWw  2vH58mhkEl8GdcDug1OwWg
#
#    stars                                               text  \
# 0    4.0  Apparently Prides Osteria had a rough summer a...
# 1    4.0  Came with friends, split the funghi pizza and ...
# 2    4.0  Went for late lunch had the combination seafoo...
# 3    5.0  We were super excited to try Sarma, having bee...
# 4    5.0  So glad we made the trip to Woburn for Gene's ...
#
#                  restaurant_name         address        city state  \
# 0                 Prides Osteria  240 Rantoul St     Beverly    MA
# 1                        Sulmona     608 Main St   Cambridge    MA
# 2   Village Roast Beef & Seafood    10 Bessom St  Marblehead    MA
# 3                          Sarma    249 Pearl St  Somerville    MA
# 4  Gene's Chinese Flatbread Cafe     466 Main St      Woburn    MA
#
#   postal_code   latitude  longitude  restaurant_rating  \
# 0       01915  42.549609 -70.884046                3.5
# 1       02139  42.362867 -71.093846                4.0
# 2       01945  42.500243 -70.859237                4.5
# 3       02145  42.388180 -71.095545                4.5
# 4       01801  42.481598 -71.150877                4.0
#
#    restaurant_review_count  is_open  \
# 0                       83        0
# 1                      220        1
# 2                       53        1
# 3                      883        1
# 4                      233        1
#
#                                           categories name  user_review_count  \
# 0  [Wine Bars, Nightlife, Farmers Market, Bars, I...  Mel                 63
# 1                  [Pizza, Italian, Nightlife, Bars]  Mel                 63
# 2                  [Seafood, American (Traditional)]  Mel                 63
# 3  [Turkish, Middle Eastern, Moroccan, Tapas/Smal...  Mel                 63
# 4                          [Cafes, Noodles, Chinese]  Mel                 63
#
#    average_stars
# 0            4.3
# 1            4.3
# 2            4.3
# 3            4.3
# 4            4.3

# %%
final_data.isnull().sum()
# Out:
# review_id                  0
# user_id                    0
# business_id                0
# stars                      0
# text                       0
# restaurant_name            0
# address                    0
# city                       0
# state                      0
# postal_code                0
# latitude                   0
# longitude                  0
# restaurant_rating          0
# restaurant_review_count    0
# is_open                    0
# categories                 0
# name                       0
# user_review_count          0
# average_stars              0
# dtype: int64

# %% [markdown]
# ### Modeling Dataset <a class="anchor" id="model"></a>

# %% [markdown]
# Creating a threshold where we are only including restaurants where `restaurant_review_count` is greater than 100.

# %%
# Filter 'final_data' DataFrame to include only rows where the 'restaurant_review_count' is greater than or equal to 100
final_data = final_data[final_data['restaurant_review_count'] >= 100]

# Print a sanity check message showing the minimum number of restaurant reviews in the filtered DataFrame
print(f"Sanity Check: The minimum amount of restaurant reviews is {final_data['restaurant_review_count'].min()}.")
# Out:
# Sanity Check: The minimum amount of restaurant reviews is 100.

# %% [markdown]
# Creating a threshold where we are only including users where `user_review_count` is greater than 100.

# %%
# Filter 'final_data' DataFrame to include only rows where the 'user_review_count' is greater than or equal to 100
final_data = final_data[final_data['user_review_count'] >= 100]

# Print a sanity check message showing the minimum number of user reviews in the filtered DataFrame
print(f"Sanity Check: The minimum amount of user reviews is {final_data['user_review_count'].min()}.")
# Out:
# Sanity Check: The minimum amount of user reviews is 100.

# %%
from sklearn import preprocessing

def label_encode_column(df, column_name, encoder_name):
    # Create an instance of the LabelEncoder
    encoder = preprocessing.LabelEncoder()

    # Use the LabelEncoder to transform the specified column
    df[column_name] = encoder.fit_transform(df[column_name])

    # Store the encoder object in the DataFrame for later use if needed
    df[encoder_name] = encoder

    return df

# %%
# Label encode the 'review_id' column in the 'final_data' DataFrame
label_encode_column(final_data, 'review_id', 'review_id_encoder')
# Out:
#          review_id                 user_id             business_id  stars  \
# 40          150339  djp57omz9cccV1wI0_sqqA  SH4c_oijp86ooTJmLvx6SQ    4.0
# 41          594094  djp57omz9cccV1wI0_sqqA  H61GvE_VbTXtQbEgTPLchg    2.0
# 42          224067  djp57omz9cccV1wI0_sqqA  rbGjumv1jiCJ6FN3rPpciA    3.0
# 43         1019629  djp57omz9cccV1wI0_sqqA  5HMXgD_gui5n0Tc_hadesg    2.0
# 44           71707  djp57omz9cccV1wI0_sqqA  EHBDrF-AIIyA_6fV4aNFpg    3.0
# ...            ...                     ...                     ...    ...
# 5572066     240578  Mc4C7fVY0sEcD-U5eOA2Og  HpiE8X3s8xRRRihjp7_IMA    4.0
# 5572085     941863  huXqrSaGyNO1aZKiM55EUg  HpiE8X3s8xRRRihjp7_IMA    5.0
# 5572508     123007  KEF5A094wOUdBG7SsS7qKg  dkiANu_mPavLe1vQNsFmjQ    4.0
# 5572754     734565  zt9FNJMJNVt65Dl1GMuJqA  071cMCITomxpMOYDMgUWeQ    5.0
# 5572793     910387  jrfAvTdjH0ykHEtJsqTRRA  071cMCITomxpMOYDMgUWeQ    5.0
#
#                                                       text  \
# 40       Cute little spot. Three of us stopped in for l...
# 41       As much as we like the waitstaff here, the foo...
# 42       This is a nothing fancy kinda joint, with kick...
# 43       I had a 5 minute honeymoon with The Gallows wh...
# 44       Antique Table is ok, but it's going to have to...
# ...                                                    ...
# 5572066  Quality Italian food and good service in an at...
# 5572085  Ahhhhmazing Chicken Cacciatore!!! And Sunday G...
# 5572508  If you're looking for a burger and wings you c...
# 5572754  Visiting from out of town and this came up in ...
# 5572793  Did someone say hot pot and Korean BBQ?  This ...
#
#                    restaurant_name                           address  \
# 40                      Thaitation                     129 Jersey St
# 41           Howling Wolf Taqueria                   76 Lafayette St
# 42               Santarpio's Pizza                     71 Newbury St
# 43                     The Gallows                1395 Washington St
# 44                   Antique Table                        2 Essex St
# ...                            ...                               ...
# 5572066      Mia's Italian Kitchen             8717 International Dr
# 5572085      Mia's Italian Kitchen             8717 International Dr
# 5572508  Jimmy’s Burgers and Wings  5256 W Irlo Bronson Memorial Hwy
# 5572754      Volcano Hot Pot & BBQ  5877 W Irlo Bronson Memorial Hwy
# 5572793      Volcano Hot Pot & BBQ  5877 W Irlo Bronson Memorial Hwy
#
#               city state postal_code   latitude  longitude  restaurant_rating  \
# 40          Boston    MA       02215  42.342315 -71.097004                4.0
# 41           Salem    MA       01970  42.519292 -70.893730                4.0
# 42         Peabody    MA       01960  42.527896 -70.993317                3.0
# 43          Boston    MA       02118  42.341343 -71.070251                4.0
# 44            Lynn    MA       01902  42.475805 -70.926544                4.0
# ...            ...   ...         ...        ...        ...                ...
# 5572066    Orlando    FL       32819  28.439125 -81.470086                4.5
# 5572085    Orlando    FL       32819  28.439125 -81.470086                4.5
# 5572508  Kissimmee    FL       34746  28.332246 -81.493330                4.0
# 5572754  Kissimmee    FL       34746  28.333532 -81.518989                4.5
# 5572793  Kissimmee    FL       34746  28.333532 -81.518989                4.5
#
#          restaurant_review_count  is_open  \
# 40                           315        1
# 41                           964        1
# 42                           359        1
# 43                           859        1
# 44                           201        1
# ...                          ...      ...
# 5572066                      532        1
# 5572085                      532        1
# 5572508                      256        1
# 5572754                      280        1
# 5572793                      280        1
#
#                                                 categories       name  \
# 40                                                  [Thai]  Stephanie
# 41       [Bars, Arts & Entertainment, Nightlife, Music ...  Stephanie
# 42                [Pizza, American (Traditional), Italian]  Stephanie
# 43       [Seafood, Bars, American (New), American (Trad...  Stephanie
# 44                                               [Italian]  Stephanie
# ...                                                    ...        ...
# 5572066               [Pizza, Breakfast & Brunch, Italian]     Steven
# 5572085               [Pizza, Breakfast & Brunch, Italian]          K
# 5572508  [Chicken Wings, Desserts, Ice Cream & Frozen Y...    Alberto
# 5572754                        [Hot Pot, Barbeque, Korean]    Crystal
# 5572793                        [Hot Pot, Barbeque, Korean]     Connie
#
#          user_review_count  average_stars review_id_encoder
# 40                     351           3.65    LabelEncoder()
# 41                     351           3.65    LabelEncoder()
# 42                     351           3.65    LabelEncoder()
# 43                     351           3.65    LabelEncoder()
# 44                     351           3.65    LabelEncoder()
# ...                    ...            ...               ...
# 5572066                471           3.80    LabelEncoder()
# 5572085                176           4.31    LabelEncoder()
# 5572508                268           3.82    LabelEncoder()
# 5572754                147           4.38    LabelEncoder()
# 5572793                303           4.56    LabelEncoder()
#
# [1203530 rows x 20 columns]

# %%
# Label encode the 'business_id' column in the 'final_data' DataFrame
label_encode_column(final_data, 'business_id', 'business_id_encoder')
# Out:
#          review_id                 user_id  business_id  stars  \
# 40          150339  djp57omz9cccV1wI0_sqqA         6620    4.0
# 41          594094  djp57omz9cccV1wI0_sqqA         4147    2.0
# 42          224067  djp57omz9cccV1wI0_sqqA        12401    3.0
# 43         1019629  djp57omz9cccV1wI0_sqqA         1357    2.0
# 44           71707  djp57omz9cccV1wI0_sqqA         3498    3.0
# ...            ...                     ...          ...    ...
# 5572066     240578  Mc4C7fVY0sEcD-U5eOA2Og         4317    4.0
# 5572085     941863  huXqrSaGyNO1aZKiM55EUg         4317    5.0
# 5572508     123007  KEF5A094wOUdBG7SsS7qKg         9377    4.0
# 5572754     734565  zt9FNJMJNVt65Dl1GMuJqA          237    5.0
# 5572793     910387  jrfAvTdjH0ykHEtJsqTRRA          237    5.0
#
#                                                       text  \
# 40       Cute little spot. Three of us stopped in for l...
# 41       As much as we like the waitstaff here, the foo...
# 42       This is a nothing fancy kinda joint, with kick...
# 43       I had a 5 minute honeymoon with The Gallows wh...
# 44       Antique Table is ok, but it's going to have to...
# ...                                                    ...
# 5572066  Quality Italian food and good service in an at...
# 5572085  Ahhhhmazing Chicken Cacciatore!!! And Sunday G...
# 5572508  If you're looking for a burger and wings you c...
# 5572754  Visiting from out of town and this came up in ...
# 5572793  Did someone say hot pot and Korean BBQ?  This ...
#
#                    restaurant_name                           address  \
# 40                      Thaitation                     129 Jersey St
# 41           Howling Wolf Taqueria                   76 Lafayette St
# 42               Santarpio's Pizza                     71 Newbury St
# 43                     The Gallows                1395 Washington St
# 44                   Antique Table                        2 Essex St
# ...                            ...                               ...
# 5572066      Mia's Italian Kitchen             8717 International Dr
# 5572085      Mia's Italian Kitchen             8717 International Dr
# 5572508  Jimmy’s Burgers and Wings  5256 W Irlo Bronson Memorial Hwy
# 5572754      Volcano Hot Pot & BBQ  5877 W Irlo Bronson Memorial Hwy
# 5572793      Volcano Hot Pot & BBQ  5877 W Irlo Bronson Memorial Hwy
#
#               city state postal_code  ...  longitude  restaurant_rating  \
# 40          Boston    MA       02215  ... -71.097004                4.0
# 41           Salem    MA       01970  ... -70.893730                4.0
# 42         Peabody    MA       01960  ... -70.993317                3.0
# 43          Boston    MA       02118  ... -71.070251                4.0
# 44            Lynn    MA       01902  ... -70.926544                4.0
# ...            ...   ...         ...  ...        ...                ...
# 5572066    Orlando    FL       32819  ... -81.470086                4.5
# 5572085    Orlando    FL       32819  ... -81.470086                4.5
# 5572508  Kissimmee    FL       34746  ... -81.493330                4.0
# 5572754  Kissimmee    FL       34746  ... -81.518989                4.5
# 5572793  Kissimmee    FL       34746  ... -81.518989                4.5
#
#          restaurant_review_count  is_open  \
# 40                           315        1
# 41                           964        1
# 42                           359        1
# 43                           859        1
# 44                           201        1
# ...                          ...      ...
# 5572066                      532        1
# 5572085                      532        1
# 5572508                      256        1
# 5572754                      280        1
# 5572793                      280        1
#
#                                                 categories       name  \
# 40                                                  [Thai]  Stephanie
# 41       [Bars, Arts & Entertainment, Nightlife, Music ...  Stephanie
# 42                [Pizza, American (Traditional), Italian]  Stephanie
# 43       [Seafood, Bars, American (New), American (Trad...  Stephanie
# 44                                               [Italian]  Stephanie
# ...                                                    ...        ...
# 5572066               [Pizza, Breakfast & Brunch, Italian]     Steven
# 5572085               [Pizza, Breakfast & Brunch, Italian]          K
# 5572508  [Chicken Wings, Desserts, Ice Cream & Frozen Y...    Alberto
# 5572754                        [Hot Pot, Barbeque, Korean]    Crystal
# 5572793                        [Hot Pot, Barbeque, Korean]     Connie
#
#         user_review_count  average_stars  review_id_encoder  \
# 40                    351           3.65     LabelEncoder()
# 41                    351           3.65     LabelEncoder()
# 42                    351           3.65     LabelEncoder()
# 43                    351           3.65     LabelEncoder()
# 44                    351           3.65     LabelEncoder()
# ...                   ...            ...                ...
# 5572066               471           3.80     LabelEncoder()
# 5572085               176           4.31     LabelEncoder()
# 5572508               268           3.82     LabelEncoder()
# 5572754               147           4.38     LabelEncoder()
# 5572793               303           4.56     LabelEncoder()
#
#         business_id_encoder
# 40           LabelEncoder()
# 41           LabelEncoder()
# 42           LabelEncoder()
# 43           LabelEncoder()
# 44           LabelEncoder()
# ...                     ...
# 5572066      LabelEncoder()
# 5572085      LabelEncoder()
# 5572508      LabelEncoder()
# 5572754      LabelEncoder()
# 5572793      LabelEncoder()
#
# [1203530 rows x 21 columns]

# %%
# Label encode the 'user_id' column in the 'final_data' DataFrame
label_encode_column(final_data, 'user_id', 'user_id_encoder')
# Out:
#          review_id  user_id  business_id  stars  \
# 40          150339    53031         6620    4.0
# 41          594094    53031         4147    2.0
# 42          224067    53031        12401    3.0
# 43         1019629    53031         1357    2.0
# 44           71707    53031         3498    3.0
# ...            ...      ...          ...    ...
# 5572066     240578    30023         4317    4.0
# 5572085     941863    58343         4317    5.0
# 5572508     123007    26963         9377    4.0
# 5572754     734565    81015          237    5.0
# 5572793     910387    60890          237    5.0
#
#                                                       text  \
# 40       Cute little spot. Three of us stopped in for l...
# 41       As much as we like the waitstaff here, the foo...
# 42       This is a nothing fancy kinda joint, with kick...
# 43       I had a 5 minute honeymoon with The Gallows wh...
# 44       Antique Table is ok, but it's going to have to...
# ...                                                    ...
# 5572066  Quality Italian food and good service in an at...
# 5572085  Ahhhhmazing Chicken Cacciatore!!! And Sunday G...
# 5572508  If you're looking for a burger and wings you c...
# 5572754  Visiting from out of town and this came up in ...
# 5572793  Did someone say hot pot and Korean BBQ?  This ...
#
#                    restaurant_name                           address  \
# 40                      Thaitation                     129 Jersey St
# 41           Howling Wolf Taqueria                   76 Lafayette St
# 42               Santarpio's Pizza                     71 Newbury St
# 43                     The Gallows                1395 Washington St
# 44                   Antique Table                        2 Essex St
# ...                            ...                               ...
# 5572066      Mia's Italian Kitchen             8717 International Dr
# 5572085      Mia's Italian Kitchen             8717 International Dr
# 5572508  Jimmy’s Burgers and Wings  5256 W Irlo Bronson Memorial Hwy
# 5572754      Volcano Hot Pot & BBQ  5877 W Irlo Bronson Memorial Hwy
# 5572793      Volcano Hot Pot & BBQ  5877 W Irlo Bronson Memorial Hwy
#
#               city state postal_code  ...  restaurant_rating  \
# 40          Boston    MA       02215  ...                4.0
# 41           Salem    MA       01970  ...                4.0
# 42         Peabody    MA       01960  ...                3.0
# 43          Boston    MA       02118  ...                4.0
# 44            Lynn    MA       01902  ...                4.0
# ...            ...   ...         ...  ...                ...
# 5572066    Orlando    FL       32819  ...                4.5
# 5572085    Orlando    FL       32819  ...                4.5
# 5572508  Kissimmee    FL       34746  ...                4.0
# 5572754  Kissimmee    FL       34746  ...                4.5
# 5572793  Kissimmee    FL       34746  ...                4.5
#
#          restaurant_review_count  is_open  \
# 40                           315        1
# 41                           964        1
# 42                           359        1
# 43                           859        1
# 44                           201        1
# ...                          ...      ...
# 5572066                      532        1
# 5572085                      532        1
# 5572508                      256        1
# 5572754                      280        1
# 5572793                      280        1
#
#                                                 categories       name  \
# 40                                                  [Thai]  Stephanie
# 41       [Bars, Arts & Entertainment, Nightlife, Music ...  Stephanie
# 42                [Pizza, American (Traditional), Italian]  Stephanie
# 43       [Seafood, Bars, American (New), American (Trad...  Stephanie
# 44                                               [Italian]  Stephanie
# ...                                                    ...        ...
# 5572066               [Pizza, Breakfast & Brunch, Italian]     Steven
# 5572085               [Pizza, Breakfast & Brunch, Italian]          K
# 5572508  [Chicken Wings, Desserts, Ice Cream & Frozen Y...    Alberto
# 5572754                        [Hot Pot, Barbeque, Korean]    Crystal
# 5572793                        [Hot Pot, Barbeque, Korean]     Connie
#
#         user_review_count average_stars  review_id_encoder  \
# 40                    351          3.65     LabelEncoder()
# 41                    351          3.65     LabelEncoder()
# 42                    351          3.65     LabelEncoder()
# 43                    351          3.65     LabelEncoder()
# 44                    351          3.65     LabelEncoder()
# ...                   ...           ...                ...
# 5572066               471          3.80     LabelEncoder()
# 5572085               176          4.31     LabelEncoder()
# 5572508               268          3.82     LabelEncoder()
# 5572754               147          4.38     LabelEncoder()
# 5572793               303          4.56     LabelEncoder()
#
#          business_id_encoder user_id_encoder
# 40            LabelEncoder()  LabelEncoder()
# 41            LabelEncoder()  LabelEncoder()
# 42            LabelEncoder()  LabelEncoder()
# 43            LabelEncoder()  LabelEncoder()
# 44            LabelEncoder()  LabelEncoder()
# ...                      ...             ...
# 5572066       LabelEncoder()  LabelEncoder()
# 5572085       LabelEncoder()  LabelEncoder()
# 5572508       LabelEncoder()  LabelEncoder()
# 5572754       LabelEncoder()  LabelEncoder()
# 5572793       LabelEncoder()  LabelEncoder()
#
# [1203530 rows x 22 columns]

# %%
# Drop the 'review_id_encoder', 'business_id_encoder', and 'user_id_encoder' columns from the 'final_data' DataFrame
final_data = final_data.drop(['review_id_encoder', 'business_id_encoder', 'user_id_encoder'], axis=1)

# %%
# Display the first few rows of the 'final_data' DataFrame
final_data.head()
# Out:
#     review_id  user_id  business_id  stars  \
# 40     150339    53031         6620    4.0
# 41     594094    53031         4147    2.0
# 42     224067    53031        12401    3.0
# 43    1019629    53031         1357    2.0
# 44      71707    53031         3498    3.0
#
#                                                  text        restaurant_name  \
# 40  Cute little spot. Three of us stopped in for l...             Thaitation
# 41  As much as we like the waitstaff here, the foo...  Howling Wolf Taqueria
# 42  This is a nothing fancy kinda joint, with kick...      Santarpio's Pizza
# 43  I had a 5 minute honeymoon with The Gallows wh...            The Gallows
# 44  Antique Table is ok, but it's going to have to...          Antique Table
#
#                address     city state postal_code   latitude  longitude  \
# 40       129 Jersey St   Boston    MA       02215  42.342315 -71.097004
# 41     76 Lafayette St    Salem    MA       01970  42.519292 -70.893730
# 42       71 Newbury St  Peabody    MA       01960  42.527896 -70.993317
# 43  1395 Washington St   Boston    MA       02118  42.341343 -71.070251
# 44          2 Essex St     Lynn    MA       01902  42.475805 -70.926544
#
#     restaurant_rating  restaurant_review_count  is_open  \
# 40                4.0                      315        1
# 41                4.0                      964        1
# 42                3.0                      359        1
# 43                4.0                      859        1
# 44                4.0                      201        1
#
#                                            categories       name  \
# 40                                             [Thai]  Stephanie
# 41  [Bars, Arts & Entertainment, Nightlife, Music ...  Stephanie
# 42           [Pizza, American (Traditional), Italian]  Stephanie
# 43  [Seafood, Bars, American (New), American (Trad...  Stephanie
# 44                                          [Italian]  Stephanie
#
#     user_review_count  average_stars
# 40                351           3.65
# 41                351           3.65
# 42                351           3.65
# 43                351           3.65
# 44                351           3.65

# %%
# Extract specific columns 'user_id', 'business_id', 'stars', 'restaurant_name', and 'categories' from final_data
model_data = final_data[['user_id', 'business_id', 'stars', 'restaurant_name', 'categories']]

# Rename the 'stars' column to 'rating' in the 'model_data' DataFrame
model_data.rename(columns={'stars': 'rating'}, inplace=True)

# %%
# Display the first few rows of the resulting DataFrame
model_data.head()
# Out:
#     user_id  business_id  rating        restaurant_name  \
# 40    53031         6620     4.0             Thaitation
# 41    53031         4147     2.0  Howling Wolf Taqueria
# 42    53031        12401     3.0      Santarpio's Pizza
# 43    53031         1357     2.0            The Gallows
# 44    53031         3498     3.0          Antique Table
#
#                                            categories
# 40                                             [Thai]
# 41  [Bars, Arts & Entertainment, Nightlife, Music ...
# 42           [Pizza, American (Traditional), Italian]
# 43  [Seafood, Bars, American (New), American (Trad...
# 44                                          [Italian]

# %%
# Pickle the DataFrame
model_data.to_pickle('/Users/diane/Desktop/BrainStation/Brainstation_Capstone/yelp_data/model_data.pkl')

# %%
# Filter data for the city of Vancouver
vancouver_data = final_data[(final_data['city'] == 'Vancouver') & (final_data['state'] == 'BC')]

# Extract specific columns 'user_id', 'business_id', and 'stars' from final_data
vancouver_data = vancouver_data[['user_id', 'business_id', 'stars', 'restaurant_name', 'categories']]

# Rename the 'stars' column to 'rating'
vancouver_data.rename(columns={'stars': 'rating'}, inplace=True)

vancouver_data.head()
# Out:
#       user_id  business_id  rating               restaurant_name  \
# 1101    70315         1407     4.0                  Meat & Bread
# 1105    70315         1356     3.0   Edible Canada At the Market
# 1109    70315         7370     4.0  The Lamplighter Public House
# 1144    70315         1143     5.0                          Miku
# 1151    70315        13469     4.0                          Lupo
#
#                                              categories
# 1101  [Fast Food, Bakeries, Sandwiches, Salad, Soup,...
# 1105  [Seafood, Canadian (New), American (New), Spec...
# 1109                [Nightlife, Gastropubs, Bars, Pubs]
# 1144                             [Japanese, Sushi Bars]
# 1151                                          [Italian]

# %%
vancouver_data.shape
# Out:
# (64660, 5)

# %%
vancouver_data.to_pickle('/Users/diane/Desktop/BrainStation/Brainstation_Capstone/yelp_data/vancouver_data.pkl')
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
