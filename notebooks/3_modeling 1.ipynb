# %% [markdown]
# ## Modeling
#
# **Name**: Diane Lu
#
# **Contact**: dianengalu@gmail.com
#
# **Date**: 07/18/2023

# %% [markdown]
# ### Table of Contents
#
# 1. [Introduction](#intro)
# 2. [Final Dataset](#final)
#     * Data Dictionary
# 3. [Collaborative-Filtering Recommendation System without SVD](#nosvd)
# 4. [Collaborative-Filtering Recommendation System with SVD](#svd)
# 5. [Collaborative-Filtering Recommendation System with FunkSVD](#funksvd)

# %% [markdown]
# ### Introduction <a class="anchor" id="intro"></a>
#
# asdf

# %% [markdown]
# #### Importing Python Libraries
#
# Importing necessary libraries for the EDA process.

# %%
# Import the basic packages
import numpy as np 
import pandas as pd 

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import TruncatedSVD

# Import the surprise packages
from surprise import SVD
from surprise.reader import Reader
from surprise import Dataset
from surprise.prediction_algorithms.matrix_factorization import SVD as FunkSVD
from surprise.model_selection import train_test_split
from surprise.model_selection import GridSearchCV
from surprise import accuracy

import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Model Dataset <a class="anchor" id="final"></a>
#
# **Data Dictionary:**
# * `user_id`: unique user id
# * `business_id`: unique user id
# * `rating`: star rating

# %%
model_data = pd.read_pickle('/Users/diane/Desktop/BrainStation/Brainstation_Capstone/yelp_data/model_data.pkl')

# %%
model_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1203530 entries, 40 to 5572793
# Data columns (total 5 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   user_id          1203530 non-null  int64
#  1   business_id      1203530 non-null  int64
#  2   rating           1203530 non-null  float64
#  3   restaurant_name  1203530 non-null  object
#  4   categories       1203530 non-null  object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 55.1+ MB

# %%
model_data.head()
# Out:
#     user_id  business_id  rating        restaurant_name  \
# 40    53031         6620     4.0             Thaitation
# 41    53031         4147     2.0  Howling Wolf Taqueria
# 42    53031        12401     3.0      Santarpio's Pizza
# 43    53031         1357     2.0            The Gallows
# 44    53031         3498     3.0          Antique Table
#
#                                            categories
# 40                                             [Thai]
# 41  [Bars, Arts & Entertainment, Nightlife, Music ...
# 42           [Pizza, American (Traditional), Italian]
# 43  [Seafood, Bars, American (New), American (Trad...
# 44                                          [Italian]

# %%
model_data.isnull().sum()
# Out:
# user_id            0
# business_id        0
# rating             0
# restaurant_name    0
# categories         0
# dtype: int64

# %%
print(f"The size of our model dataset is {model_data.shape[0]} entries.")
# Out:
# The size of our model dataset is 1203530 entries.

# %%
sampled_model_data = model_data.sample(frac=0.01, random_state=42)

print(f"The size of our sampled model dataset is {sampled_model_data.shape[0]} entries.")
# Out:
# The size of our sampled model dataset is 12035 entries.

# %% [markdown]
# ### Collaborative-Filtering Recommendation System without SVD <a class="anchor" id="nosvd"></a>
#
# Collaborative filtering is a general technique used in recommendation systems to predict user preferences based on the preferences of similar users. It does not involve matrix factorization. Instead, it relies on computing similarities between users or items to generate recommendations. Collaborative filtering without SVD directly operates on the user-item interaction matrix and may use various similarity metrics to find similar users or items.

# %%
# User-Item Interaction Matrix
user_item_matrix = sampled_model_data.pivot_table(index='user_id', columns='business_id', values='rating')
user_item_matrix.sample(5)
# Out:
# business_id  2      4      5      6      8      9      10     11     13     \
# user_id
# 71152          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 15950          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 67142          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 77691          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 61003          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# business_id  14     ...  14301  14305  14306  14308  14310  14313  14315  \
# user_id             ...
# 71152          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 15950          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 67142          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 77691          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 61003          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# business_id  14317  14318  14321
# user_id
# 71152          NaN    NaN    NaN
# 15950          NaN    NaN    NaN
# 67142          NaN    NaN    NaN
# 77691          NaN    NaN    NaN
# 61003          NaN    NaN    NaN
#
# [5 rows x 6649 columns]

# %%
print(f"The shape of the user item matrix is {user_item_matrix.shape[0]} by {user_item_matrix.shape[1]}.")
# Out:
# The shape of the user item matrix is 8981 by 6649.

# %%
# Normalize user-item matrix
user_item_matrix_norm = user_item_matrix.subtract(user_item_matrix.mean(axis=1), axis = 'rows')
user_item_matrix_norm.head()
# Out:
# business_id  2      4      5      6      8      9      10     11     13     \
# user_id
# 4              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 27             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# business_id  14     ...  14301  14305  14306  14308  14310  14313  14315  \
# user_id             ...
# 4              NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10             NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18             NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25             NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 27             NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# business_id  14317  14318  14321
# user_id
# 4              NaN    NaN    NaN
# 10             NaN    NaN    NaN
# 18             NaN    NaN    NaN
# 25             NaN    NaN    NaN
# 27             NaN    NaN    NaN
#
# [5 rows x 6649 columns]

# %%
# User similarity matrix using Pearson correlation
user_similarity = user_item_matrix_norm.T.corr()
user_similarity.head()
# Out:
# user_id  4      10     18     25     27     28     36     49     57     60     \
# user_id
# 4          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 27         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# user_id  ...  81055  81063  81091  81092  81094  81101  81115  81130  81132  \
# user_id  ...
# 4        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 27       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# user_id  81133
# user_id
# 4          NaN
# 10         NaN
# 18         NaN
# 25         NaN
# 27         NaN
#
# [5 rows x 8981 columns]

# %%
# Pick a user ID
picked_userid = 67142

# Remove picked user ID from the candidate list
user_similarity.drop(index=picked_userid, inplace=True)

# Take a look at the data
user_similarity.head()
# Out:
# user_id  4      10     18     25     27     28     36     49     57     60     \
# user_id
# 4          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 27         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# user_id  ...  81055  81063  81091  81092  81094  81101  81115  81130  81132  \
# user_id  ...
# 4        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 27       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# user_id  81133
# user_id
# 4          NaN
# 10         NaN
# 18         NaN
# 25         NaN
# 27         NaN
#
# [5 rows x 8981 columns]

# %%
# Number of similar users
n = 10

# User similarity threashold
user_similarity_threshold = 0.3

# Get top n similar users
similar_users = user_similarity[user_similarity[picked_userid]>user_similarity_threshold][picked_userid].sort_values(ascending=False)[:n]
Q
# Print out top n similar users
print(f'The similar users for user {picked_userid} are', similar_users)
# Out:
# The similar users for user 67142 are Series([], Name: 67142, dtype: float64)

# %%
# Calculate the similarity matrix 
similarity_matrix = user_item_matrix.corr()

# %%
# Choose a user for whom we want to make recommendations (e.g., user_id = 5)
target_user_id = 53031

# Get the ratings of the target user
target_user_ratings = user_item_matrix.loc[target_user_id]

# Find similar users to the target user based on the similarity matrix
similar_users = similarity_matrix[target_user_id].drop(target_user_id).sort_values(ascending=False)

# Filter out restaurants the target user has already rated
unrated_restaurants = target_user_ratings[target_user_ratings == 0].index

# Make restaurant recommendations based on the ratings of similar users
recommendations = pd.Series()
for restaurant_id in unrated_restaurants:
    similar_users_ratings = user_item_matrix.loc[similar_users.index, restaurant_id]
    weighted_rating = sum(similar_users_ratings * similar_users) / sum(similar_users)
    recommendations[restaurant_id] = weighted_rating

# Sort the recommendations in descending order
recommendations = recommendations.sort_values(ascending=False)

print("Restaurant recommendations for User {}: \n{}".format(target_user_id, recommendations))

# %%
# Function to get top N recommendations for a user
def get_top_N_recommendations(user_id, N=5):
    user_index = user_item_matrix.index.get_loc(user_id)

    similar_users = user_similarity[user_index]

    top_similar_users_indices = similar_users.argsort()[::-1][1:N+1]  # Exclude the user itself

    top_recommendations = user_item_matrix.iloc[top_similar_users_indices].mean(axis=0)
    top_recommendations = top_recommendations.sort_values(ascending=False)
    
    return top_recommendations.index.tolist()

# %%
# Example: Get top 5 recommendations for a user 
user_id = 53031
top_recommendations = get_top_N_recommendations(user_id, N=5)
print(top_recommendations)
# Out:
# [10817, 13179, 10569, 4256, 6333, 1675, 901, 6465, 2527, 9567, 9560, 9566, 9571, 9574, 9564, 9575, 9577, 2, 9558, 9580, 9547, 9546, 9545, 9540, 9539, 9536, 9534, 9533, 9529, 9526, 9523, 9549, 9589, 9583, 9584, 9626, 9625, 9624, 9619, 9618, 9617, 9614, 9613, 9611, 9608, 9607, 9604, 9600, 9597, 9596, 9595, 9593, 9592, 9591, 9521, 9587, 9522, 9516, 9520, 9432, 9456, 9455, 9452, 9451, 9450, 9444, 9442, 9441, 9437, 9433, 9427, 9458, 9426, 9425, 9422, 9414, 9411, 9409, 9405, 9403, 9402, 9400, 9457, 9459, 9519, 9493, 9628, 9515, 9512, 9508, 9506, 9504, 9503, 9500, 9495, 9494, 9483, 9461, 9480, 9477, 9473, 9470, 9469, 9468, 9466, 9465, 9463, 9462, 9627, 9643, 9634, 9780, 9806, 9804, 9799, 9798, 9796, 9789, 9788, 9786, 9783, 9782, 9779, 9752, 9774, 9772, 9771, 9769, 9766, 9762, 9760, 9759, 9758, 9754, 9807, 9808, 9810, 9811, 9863, 9862, 9861, 9860, 9857, 9854, 9844, 9842, 9840, 9837, 9836, 9834, 9829, 9828, 9827, 9825, 9824, 9822, 9818, 9815, 9813, 9753, 9750, 9635, 9659, 9686, 9680, 9679, 9675, 9674, 9673, 9665, 9664, 9663, 9661, 9654, 9749, 9651, 9650, 9649, 9648, 9647, 9645, 9644, 9394, 9641, 9637, 9688, 9693, 9695, 9696, 9747, 9746, 9742, 9741, 9740, 9738, 9737, 9736, 9731, 9728, 9726, 9723, 9721, 9720, 9715, 9710, 9709, 9708, 9705, 9698, 9697, 9396, 9385, 9392, 9869, 9081, 9080, 9079, 9077, 9075, 9074, 9069, 9066, 9062, 9058, 9054, 9053, 9049, 9048, 9042, 9034, 9033, 9031, 9030, 9027, 9026, 9025, 9023, 9083, 9084, 9085, 9110, 9140, 9138, 9134, 9129, 9128, 9126, 9119, 9118, 9115, 9114, 9109, 9088, 9106, 9105, 9104, 9102, 9100, 9099, 9098, 9097, 9093, 9091, 9022, 9021, 9015, 8924, 8945, 8943, 8942, 8940, 8939, 8938, 8935, 8931, 8929, 8926, 8920, 8952, 8919, 8918, 8915, 8914, 8912, 8908, 8904, 8901, 8898, 8897, 8949, 8954, 9014, 8982, 9012, 9009, 9008, 9004, 9003, 8999, 8992, 8989, 8988, 8984, 8980, 8959, 8977, 8976, 8970, 8967, 8966, 8965, 8964, 8963, 8961, 8960, 9141, 9142, 9144, 9300, 9319, 9318, 9315, 9314, 9312, 9308, 9307, 9305, 9304, 9302, 9299, 9324, 9292, 9289, 9284, 9283, 9282, 9281, 9277, 9275, 9273, 9272, 9321, 9325, 9270, 9354, 9383, 9382, 9380, 9378, 9375, 9367, 9366, 9365, 9364, 9358, 9352, 9326, 9350, 9349, 9347, 9343, 9340, 9339, 9335, 9334, 9333, 9329, 9271, 9267, 9148, 9182, 9207, 9204, 9201, 9200, 9190, 9189, 9186, 9185, 9184, 9183, 9178, 9217, 9170, 9169, 9167, 9166, 9164, 9162, 9158, 9155, 9153, 9151, 9209, 9220, 9266, 9247, 9263, 9262, 9260, 9259, 9258, 9254, 9253, 9252, 9251, 9248, 9244, 9221, 9242, 9239, 9236, 9235, 9234, 9233, 9231, 9230, 9225, 9223, 9866, 9874, 9870, 10453, 10473, 10472, 10471, 10467, 10466, 10465, 10463, 10460, 10458, 10455, 10452, 10478, 10450, 10449, 10447, 10446, 10441, 10440, 10437, 10436, 10431, 10430, 10477, 10479, 10428, 10514, 10543, 10542, 10540, 10530, 10528, 10527, 10524, 10522, 10519, 10515, 10512, 10482, 10509, 10508, 10507, 10506, 10504, 10500, 10494, 10492, 10490, 10488, 10429, 10427, 10545, 10334, 10364, 10361, 10359, 10358, 10352, 10349, 10348, 10340, 10339, 10337, 10333, 10367, 10326, 10325, 10324, 10321, 10320, 10319, 10314, 10313, 10311, 10308, 10366, 10368, 10426, 10398, 10425, 10424, 10423, 10422, 10416, 10413, 10410, 10409, 10407, 10404, 10394, 10370, 10392, 10391, 10390, 10388, 10379, 10378, 10377, 10376, 10374, 10372, 10544, 10548, 9872, 10700, 10722, 10721, 10713, 10712, 10710, 10709, 10708, 10706, 10704, 10703, 10699, 10724, 10694, 10693, 10690, 10685, 10680, 10679, 10677, 10673, 10671, 10668, 10723, 10725, 10666, 10750, 10773, 10771, 10767, 10766, 10764, 10760, 10759, 10756, 10754, 10753, 10746, 10727, 10744, 10743, 10742, 10741, 10737, 10735, 10733, 10730, 10729, 10728, 10667, 10663, 10549, 10576, 10601, 10600, 10599, 10597, 10596, 10595, 10592, 10590, 10586, 10577, 10575, 10604, 10574, 10570, 10567, 10564, 10561, 10559, 10558, 10557, 10553, 10552, 10603, 10605, 10660, 10628, 10659, 10651, 10648, 10645, 10643, 10642, 10640, 10639, 10638, 10634, 10626, 10606, 10620, 10619, 10618, 10615, 10614, 10613, 10612, 10611, 10610, 10607, 10307, 10306, 10303, 10007, 10023, ...

# %%
# User-Item Interaction Matrix
user_item_matrix = model_data.pivot_table(index='user_id', columns='business_id', values='ratingg')

# %%
# Fill missing values (NaNs) with zeros
user_item_matrix = user_item_matrix.fillna(0)

# %%
user_item_matrix.shape
# Out:
# (81142, 14323)

# %%
# Displaying the first few rows to get an initial glimpse of the data
user_item_matrix.head()
# Out:
# business_id             --164t1nclzzmca7eDiJMw  --Q3mAcX9t63f7Xcbn7LVA  \
# user_id
# --0zxhZTSLZ7w1hUD2bEwA                     0.0                     0.0
# --17Db1K-KujRuN7hY9Z0Q                     0.0                     0.0
# --2vR0DIsmQ6WfcSzKWigw                     0.0                     0.0
# --3WaS23LcIXtxyFULJHTA                     0.0                     0.0
# --3l8wysfp49Z2TLnyT0vg                     0.0                     0.0
#
# business_id             --UNNdnHRhsyFUbDgumdtQ  -0A60UZl9nbdq2WWySJ_tQ  \
# user_id
# --0zxhZTSLZ7w1hUD2bEwA                     0.0                     0.0
# --17Db1K-KujRuN7hY9Z0Q                     0.0                     0.0
# --2vR0DIsmQ6WfcSzKWigw                     0.0                     0.0
# --3WaS23LcIXtxyFULJHTA                     0.0                     0.0
# --3l8wysfp49Z2TLnyT0vg                     0.0                     0.0
#
# business_id             -0iqnv7MjKrgh7Q7bYRlUQ  -0sIQ96u8XevGUXZ--pvaA  \
# user_id
# --0zxhZTSLZ7w1hUD2bEwA                     0.0                     0.0
# --17Db1K-KujRuN7hY9Z0Q                     0.0                     0.0
# --2vR0DIsmQ6WfcSzKWigw                     0.0                     0.0
# --3WaS23LcIXtxyFULJHTA                     0.0                     0.0
# --3l8wysfp49Z2TLnyT0vg                     0.0                     0.0
#
# business_id             -1ShItlulHnBsoOQWnblzw  -1h2qkElNfKjUPw6brMbIw  \
# user_id
# --0zxhZTSLZ7w1hUD2bEwA                     0.0                     0.0
# --17Db1K-KujRuN7hY9Z0Q                     0.0                     0.0
# --2vR0DIsmQ6WfcSzKWigw                     0.0                     0.0
# --3WaS23LcIXtxyFULJHTA                     0.0                     0.0
# --3l8wysfp49Z2TLnyT0vg                     0.0                     0.0
#
# business_id             -1mmKpu7b_NlBit2pOOPnQ  -1sIJLX71taHD-BgbwY64Q  ...  \
# user_id                                                                 ...
# --0zxhZTSLZ7w1hUD2bEwA                     0.0                     0.0  ...
# --17Db1K-KujRuN7hY9Z0Q                     0.0                     0.0  ...
# --2vR0DIsmQ6WfcSzKWigw                     0.0                     0.0  ...
# --3WaS23LcIXtxyFULJHTA                     0.0                     0.0  ...
# --3l8wysfp49Z2TLnyT0vg                     0.0                     0.0  ...
#
# business_id             zvKfCAOBzVcxc1HLpoIY8A  zwKIQgthba1FUPWS7nOo0w  \
# user_id
# --0zxhZTSLZ7w1hUD2bEwA                     0.0                     0.0
# --17Db1K-KujRuN7hY9Z0Q                     0.0                     0.0
# --2vR0DIsmQ6WfcSzKWigw                     0.0                     0.0
# --3WaS23LcIXtxyFULJHTA                     0.0                     0.0
# --3l8wysfp49Z2TLnyT0vg                     0.0                     0.0
#
# business_id             zwhSGiftT_yzKSEmMCol6Q  zwn53gHyn1NlX9h3jKFOUg  \
# user_id
# --0zxhZTSLZ7w1hUD2bEwA                     0.0                     0.0
# --17Db1K-KujRuN7hY9Z0Q                     0.0                     0.0
# --2vR0DIsmQ6WfcSzKWigw                     0.0                     0.0
# --3WaS23LcIXtxyFULJHTA                     0.0                     0.0
# --3l8wysfp49Z2TLnyT0vg                     0.0                     0.0
#
# business_id             zyBC3BUkH9klhPhMyQmxAQ  zyHMtStYlKG67WRprp6GZQ  \
# user_id
# --0zxhZTSLZ7w1hUD2bEwA                     0.0                     0.0
# --17Db1K-KujRuN7hY9Z0Q                     0.0                     0.0
# --2vR0DIsmQ6WfcSzKWigw                     0.0                     0.0
# --3WaS23LcIXtxyFULJHTA                     0.0                     0.0
# --3l8wysfp49Z2TLnyT0vg                     0.0                     0.0
#
# business_id             zyauuvAYdVweBK4L7wBRmw  zz4WGzntV59HqhefV5zigQ  \
# user_id
# --0zxhZTSLZ7w1hUD2bEwA                     0.0                     0.0
# --17Db1K-KujRuN7hY9Z0Q                     0.0                     0.0
# --2vR0DIsmQ6WfcSzKWigw                     0.0                     0.0
# --3WaS23LcIXtxyFULJHTA                     0.0                     0.0
# --3l8wysfp49Z2TLnyT0vg                     0.0                     0.0
#
# business_id             zzin1d1oHi81GuI0ufo1VA  zzlkjDG9Rv8Jn-vSolMgyw
# user_id
# --0zxhZTSLZ7w1hUD2bEwA                     0.0                     0.0
# --17Db1K-KujRuN7hY9Z0Q                     0.0                     0.0
# --2vR0DIsmQ6WfcSzKWigw                     0.0                     0.0
# --3WaS23LcIXtxyFULJHTA                     0.0                     0.0
# --3l8wysfp49Z2TLnyT0vg                     0.0                     0.0
#
# [5 rows x 14323 columns]

# %%
similarity_scores = cosine_similarity(user_item_matrix)
similarity_scores.shape
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def recommend(business_id):
    # Find the index of the input restaurant name in the pivot table
    index = np.where(user_item_matrix.index == business_id)[0][0]

    # Retrieve the similarity scores of the input restaurant with other restaurants,
    # sort them in descending order, and select the top 4 similar items
    similar_items = sorted(list(enumerate(similarity_scores[index])), key=lambda x: x[1], reverse=True)[1:5]

    # Initialize an empty list to store recommended restaurant names
    data = []

    # Iterate through each similar item
    for i in similar_items:
        # Fetch the relevant restaurant name from the 'business_data' dataset
        similar_business_id = user_item_matrix.index[i[0]]

        # Append the restaurant name to the 'data' list
        data.append(similar_business_id)

    # Return the 'data' list containing names of the recommended restaurants
    return data

# %% [markdown]
# ### Collaborative-Filtering Recommendation System with SVD <a class="anchor" id="svd"></a>
#
# Traditional Singular Value Decomposition is a matrix factorization technique that decomposes a given matrix into three matrices: U (user features), Σ (singular values), and V^T (item features). While traditional SVD can be applied to recommendation systems, it assumes a complete user-item interaction matrix without any missing values. This assumption is often not applicable in real-world scenarios where user-item matrices are typically sparse.

# %%
# User-Item Interaction Matrix
user_item_matrix = model_data.pivot_table(index='user_id', columns='business_id', values='rating').fillna(0)
user_item_matrix.sample(5)
# Out:
# restaurant_name          Gruby's New York Deli  'Ohana  /pôr/ wine house  \
# user_id
# UZRYHUjRmNrPOTjmCa4_gg                     0.0     0.0               0.0
# wBT7zqYaMMfsuhHKB5XqgQ                     0.0     0.0               0.0
# RkLluG0LGXiJgf2i9dGmDQ                     0.0     0.0               0.0
# 5AL4m5Nh1P91HuKxewdWPQ                     0.0     0.0               0.0
# IBOnLGJ4jEti15dw-nasPA                     0.0     0.0               0.0
#
# restaurant_name         10 Barrel Brewing Portland  10 Degrees South  \
# user_id
# UZRYHUjRmNrPOTjmCa4_gg                         0.0               0.0
# wBT7zqYaMMfsuhHKB5XqgQ                         0.0               0.0
# RkLluG0LGXiJgf2i9dGmDQ                         0.0               0.0
# 5AL4m5Nh1P91HuKxewdWPQ                         0.0               0.0
# IBOnLGJ4jEti15dw-nasPA                         0.0               0.0
#
# restaurant_name         101 Beer Kitchen  101 By Teahaus  101 Steak  \
# user_id
# UZRYHUjRmNrPOTjmCa4_gg               0.0             0.0        0.0
# wBT7zqYaMMfsuhHKB5XqgQ               0.0             0.0        0.0
# RkLluG0LGXiJgf2i9dGmDQ               0.0             0.0        0.0
# 5AL4m5Nh1P91HuKxewdWPQ               0.0             0.0        0.0
# IBOnLGJ4jEti15dw-nasPA               0.0             0.0        0.0
#
# restaurant_name         10th & Piedmont  110 Grill  ...  laV  mmmpanadas  \
# user_id                                             ...
# UZRYHUjRmNrPOTjmCa4_gg              0.0        0.0  ...  0.0         0.0
# wBT7zqYaMMfsuhHKB5XqgQ              0.0        0.0  ...  0.0         0.0
# RkLluG0LGXiJgf2i9dGmDQ              0.0        0.0  ...  0.0         0.0
# 5AL4m5Nh1P91HuKxewdWPQ              0.0        0.0  ...  0.0         0.0
# IBOnLGJ4jEti15dw-nasPA              0.0        0.0  ...  0.0         0.0
#
# restaurant_name         nati's southern seafood boil  sweetgreen  wagamama  \
# user_id
# UZRYHUjRmNrPOTjmCa4_gg                           0.0         0.0       0.0
# wBT7zqYaMMfsuhHKB5XqgQ                           0.0         0.0       0.0
# RkLluG0LGXiJgf2i9dGmDQ                           0.0         0.0       0.0
# 5AL4m5Nh1P91HuKxewdWPQ                           0.0         0.0       0.0
# IBOnLGJ4jEti15dw-nasPA                           0.0         0.0       0.0
#
# restaurant_name         wagamama - faneuil hall  wagamama - prudential  \
# user_id
# UZRYHUjRmNrPOTjmCa4_gg                      0.0                    0.0
# wBT7zqYaMMfsuhHKB5XqgQ                      0.0                    0.0
# RkLluG0LGXiJgf2i9dGmDQ                      0.0                    0.0
# 5AL4m5Nh1P91HuKxewdWPQ                      0.0                    0.0
# IBOnLGJ4jEti15dw-nasPA                      0.0                    0.0
#
# restaurant_name         wagamama - seaport  zpizza  ñoños tacos
# user_id
# UZRYHUjRmNrPOTjmCa4_gg                 0.0     0.0          0.0
# wBT7zqYaMMfsuhHKB5XqgQ                 0.0     0.0          0.0
# RkLluG0LGXiJgf2i9dGmDQ                 0.0     0.0          0.0
# 5AL4m5Nh1P91HuKxewdWPQ                 0.0     0.0          0.0
# IBOnLGJ4jEti15dw-nasPA                 0.0     0.0          0.0
#
# [5 rows x 12192 columns]

# %%
# Traditional SVD
svd = TruncatedSVD(n_components=50) 
user_features = svd.fit_transform(user_item_matrix)

# %%
# Function to get top N recommendations for a user using Traditional SVD
def get_top_N_recommendations_svd(user_id, N=5):
    user_index = user_item_matrix.index.get_loc(user_id)
    user_feature = user_features[user_index]

    predicted_ratings = pd.Series(user_features.dot(svd.components_)[user_index])

    top_recommendations = predicted_ratings.sort_values(ascending=False)

    return top_recommendations.index.tolist()[:N]

# %%
# Example: Get top 5 recommendations for a user with user_id = 123 using Traditional SVD
user_id = 'UZRYHUjRmNrPOTjmCa4_gg'
top_recommendations_svd = get_top_N_recommendations_svd(user_id, N=5)
print(top_recommendations_svd)
# Out:
# [8335, 10217, 12180, 11548, 3779]

# %% [markdown]
# ### Collaborative-Filtering Recommendation System with FunkSVD <a class="anchor" id="funksvd"></a>
#
# FunkSVD is a specific variant of SVD designed for collaborative filtering tasks in recommendation systems. It addresses the sparsity issue present in user-item interaction matrices by incorporating stochastic gradient descent to handle missing values efficiently. FunkSVD performs matrix factorization and decomposes the user-item interaction matrix into user and item latent feature matrices.

# %%
# User-Item Interaction Matrix
user_item_matrix = sampled_model_data.pivot_table(index='user_id', columns='business_id', values='rating')
user_item_matrix.sample(5)
# Out:
# business_id  2      4      5      6      8      9      10     11     13     \
# user_id
# 53394          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 57999          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 47608          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18551          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19621          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# business_id  14     ...  14301  14305  14306  14308  14310  14313  14315  \
# user_id             ...
# 53394          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 57999          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 47608          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18551          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19621          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# business_id  14317  14318  14321
# user_id
# 53394          NaN    NaN    NaN
# 57999          NaN    NaN    NaN
# 47608          NaN    NaN    NaN
# 18551          NaN    NaN    NaN
# 19621          NaN    NaN    NaN
#
# [5 rows x 6649 columns]

# %%
# FunkSVD
def FunkSVD(matrix, latent_features=50, learning_rate=0.0002, epochs=100):
    user_matrix = np.random.rand(matrix.shape[0], latent_features)
    item_matrix = np.random.rand(matrix.shape[1], latent_features)
    
    for _ in range(epochs):
        for i in range(matrix.shape[0]):
            for j in range(matrix.shape[1]):
                if matrix[i, j] > 0:
                    error = matrix[i, j] - np.dot(user_matrix[i, :], item_matrix[j, :].T)
                    for k in range(latent_features):
                        user_matrix[i, k] += learning_rate * (2 * error * item_matrix[j, k])
                        item_matrix[j, k] += learning_rate * (2 * error * user_matrix[i, k])
    
    return user_matrix, item_matrix

# %%
# Function to get top N recommendations for a user using FunkSVD
def get_top_N_recommendations_funksvd(user_id, N=5):
    user_index = user_item_matrix.index.get_loc(user_id)
    user_feature = user_matrix[user_index]

    predicted_ratings = pd.Series(user_matrix.dot(item_matrix.T)[user_index])

    top_recommendations = predicted_ratings.sort_values(ascending=False)
    
    return top_recommendations.index.tolist()[:N]

# %%
# Example: Get top 5 recommendations for a user 
user_id = 53031
top_recommendations_funksvd = get_top_N_recommendations_funksvd(user_id, N=5)
print(top_recommendations_funksvd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Example: Get top 5 recommendations for a user
#       2 user_id = 53031
# ----> 3 top_recommendations_funksvd = get_top_N_recommendations_funksvd(user_id, N=5)
#       4 print(top_recommendations_funksvd)
#
# Cell In[14], line 4, in get_top_N_recommendations_funksvd(user_id, N)
#       2 def get_top_N_recommendations_funksvd(user_id, N=5):
#       3     user_index = user_item_matrix.index.get_loc(user_id)
# ----> 4     user_feature = user_matrix[user_index]
#       6     predicted_ratings = pd.Series(user_matrix.dot(item_matrix.T)[user_index])
#       8     top_recommendations = predicted_ratings.sort_values(ascending=False)
#
# NameError: name 'user_matrix' is not defined

# %%
# User-Item Interaction Matrix
user_item_matrix = sampled_model_data.pivot_table(index='user_id', columns='business_id', values='rating')

# %%
user_item_matrix.shape
# Out:
# (8981, 6649)

# %%
# Displaying the first few rows to get an initial glimpse of the data
user_item_matrix.head()
# Out:
# business_id  2      4      5      6      8      9      10     11     13     \
# user_id
# 4              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 27             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# business_id  14     ...  14301  14305  14306  14308  14310  14313  14315  \
# user_id             ...
# 4              NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10             NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18             NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25             NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 27             NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# business_id  14317  14318  14321
# user_id
# 4              NaN    NaN    NaN
# 10             NaN    NaN    NaN
# 18             NaN    NaN    NaN
# 25             NaN    NaN    NaN
# 27             NaN    NaN    NaN
#
# [5 rows x 6649 columns]

# %%
user_item_matrix.columns
# Out:
# Index([    2,     4,     5,     6,     8,     9,    10,    11,    13,    14,
#        ...
#        14301, 14305, 14306, 14308, 14310, 14313, 14315, 14317, 14318, 14321],
#       dtype='int64', name='business_id', length=6649)

# %%
# Set the reader with accurate rating scale
my_reader = Reader(rating_scale=(1, 5))

# Create the dataset using the reader object and the rating DataFrame
my_dataset = Dataset.load_from_df(model_data[['user_id', 'business_id', 'rating']], my_reader)

# %%
my_dataset

# %%
# Set the parameter grid
param_grid = {
    'n_factors': [100, 150], 
    'n_epochs': [10, 20],
    'lr_all': [0.005, 0.1],
    'biased': [False] } #The parameter indicates to the algorithm that all latent information must be stored. 

# Set GridSearchCV with 3 cross-validation
GS = GridSearchCV(SVD, param_grid, measures=['fcp'], cv=3)

# Fit the model with the grid search on the training set
GS.fit(my_dataset)

# Get the best hyperparameters
best_params = GS.best_params['fcp']
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'n_factors': 150, 'n_epochs': 10, 'lr_all': 0.005, 'biased': False}

# %%
# Split train-test set 
trainset, testset = train_test_split(my_dataset, test_size=0.25)

# %%
# Set the algorithm
my_svd = FunkSVD(n_factors=100, 
                 n_epochs=10, 
                 lr_all=0.005, 
                 biased=False,
                 verbose=0)
# Fit train set
my_svd.fit(trainset)

# Test the algorithm using test set
my_pred = my_svd.test(testset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Set the algorithm
# ----> 2 my_svd = FunkSVD(n_factors=100,
#       3                  n_epochs=10,
#       4                  lr_all=0.005,
#       5                  biased=False,
#       6                  verbose=0)
#       7 # Fit train set
#       8 my_svd.fit(trainset)
#
# TypeError: FunkSVD() got an unexpected keyword argument 'n_factors'

# %%
# Access the P and Q matrices from the fitted model
P = my_svd.pu  # User matrix (P)
P
Q = my_svd.qi  # Item matrix (Q)
Q
# Out:
# array([[ 0.06194114, -0.14112599, -0.31683039, ..., -0.16282319,
#          0.17948535, -0.2134076 ],
#        [-0.34110531,  0.29034201, -0.00711049, ...,  0.06596525,
#          0.34702696, -0.17407634],
#        [-0.13488896,  0.43430532, -0.50093401, ..., -0.14135051,
#          0.17353653,  0.30471074],
#        ...,
#        [-0.02159553,  0.13798291,  0.01950472, ..., -0.07777211,
#         -0.0902592 , -0.04440696],
#        [-0.08594597,  0.1347763 , -0.08041756, ...,  0.09145995,
#          0.18483861, -0.16068039],
#        [-0.19825591, -0.11820167, -0.01589753, ...,  0.19685929,
#          0.00525314, -0.26347986]])

# %%
# Put my_pred result in a dataframe
df_prediction = pd.DataFrame(my_pred, columns=['user_id',
                                                'business_id',
                                                'actual',
                                                'prediction',
                                                'details'])

# Calculate the difference of actual and prediction into diff column
df_prediction['diff'] = abs(df_prediction['prediction'] - 
                            df_prediction['actual'])

# %%
# Check the df_prediction
df_prediction.head()
# Out:
#                   user_id             business_id  actual  prediction  \
# 0  hYlCMQ278BvKv9IP9v_m4w  Dinesty Dumpling House     1.0    3.298706
# 1  XUQjZyApQXImNifP-2tAFQ   The Original Hoffbrau     5.0    3.201321
# 2  Pf7FI0OukC_CEcCz0ZxoUw              KOi Fusion     5.0    4.448637
# 3  g37Y_WmgPcJI9bf_kPV2Og           First Printer     4.0    2.085826
# 4  ZveYZ3n1IOjP9H4HfFn3Yg                Fabian's     5.0    3.457422
#
#                      details      diff
# 0  {'was_impossible': False}  2.298706
# 1  {'was_impossible': False}  1.798679
# 2  {'was_impossible': False}  0.551363
# 3  {'was_impossible': False}  1.914174
# 4  {'was_impossible': False}  1.542578

# %%
# See the best 10 predictions
df_prediction.sort_values(by='diff')[:10]
# Out:
#                        user_id             business_id  actual  prediction  \
# 242072  UZ8_xqhiguIYb9Lu2Wu8og     Museum Of Fine Arts     5.0         5.0
# 49595   9EB_WZ5Lw991mrnfkzkqvQ            Sushi Zanmai     5.0         5.0
# 102938  oSN3M4_WKdlTsnpgqPDiBg  Powell's City of Books     5.0         5.0
# 240896  lGxssT2UmyNZQZWwPDgX3A             Bar Mezzana     5.0         5.0
# 102990  0d89GUvxpJG4oFeL9rtUxQ             Tako Cheena     5.0         5.0
# 240911  nxI8n6lARJpMP5SI8U9S6w               Le Pigeon     5.0         5.0
# 6394    g3UbQdtWX1Luh9_FGIeCAw  Schmidt's Sausage Haus     5.0         5.0
# 102997  Je-c4Qu5od0DwPmYeHYOVg             Screen Door     5.0         5.0
# 280476  krWkC-U2U_YAtYdAvuRwAQ       Santarpio's Pizza     5.0         5.0
# 49526   7mL5GK8Qt3iIkNHfPsGnkg        Ball Square Cafe     5.0         5.0
#
#                           details  diff
# 242072  {'was_impossible': False}   0.0
# 49595   {'was_impossible': False}   0.0
# 102938  {'was_impossible': False}   0.0
# 240896  {'was_impossible': False}   0.0
# 102990  {'was_impossible': False}   0.0
# 240911  {'was_impossible': False}   0.0
# 6394    {'was_impossible': False}   0.0
# 102997  {'was_impossible': False}   0.0
# 280476  {'was_impossible': False}   0.0
# 49526   {'was_impossible': False}   0.0

# %%
(df_prediction["diff"] <= 1).mean()
# Out:
# 0.6014563800547057

# %%
# Calculate RMSE
rmse = accuracy.rmse(my_pred)

# Calculate MAE
mae = accuracy.mae(my_pred)
# Out:
# RMSE: 1.3122
# MAE:  1.0054

# %%
def recommend(business_id, user_item_matrix, P, Q, top_n=5):
    # Find the index of the input restaurant name in the pivot table
    index = user_item_matrix.index.get_loc(business_id)

    # Predict the ratings for the input restaurant using the FunkSVD model
    predicted_ratings = np.dot(P, Q.T)
    restaurant_ratings = predicted_ratings[index, :]

    # Get the indices of top recommended restaurants based on predicted ratings
    top_indices = np.argsort(restaurant_ratings)[::-1][:top_n]

    # Convert the indices to restaurant names
    recommended_restaurants = user_item_matrix.columns[top_indices]

    return recommended_restaurants

# %%
recommend('Miku', user_item_matrix, P, Q, top_n=5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/bigdata_ml/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/envs/bigdata_ml/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/bigdata_ml/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Miku'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 recommend('Miku', user_item_matrix, P, Q, top_n=5)
#
# Cell In[58], line 3, in recommend(restaurant_name, user_item_matrix, P, Q, top_n)
#       1 def recommend(restaurant_name, user_item_matrix, P, Q, top_n=5):
#       2     # Find the index of the input restaurant name in the pivot table
# ----> 3     index = user_item_matrix.index.get_loc(restaurant_name)
#       5     # Predict the ratings for the input restaurant using the FunkSVD model
#       6     predicted_ratings = np.dot(P, Q.T)
#
# File ~/anaconda3/envs/bigdata_ml/lib/python3.8/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Miku'

# %% [markdown]
# ### Item-Item Collaborative-Filtering Recommendation System

# %%
def item_similarity_matrix(df):
    pivot_df = df.pivot(index='user_id', columns='business_id', values='rating').fillna(0)
    item_sim = np.corrcoef(pivot_df.T)
    return item_sim

item_sim_matrix = item_similarity_matrix(model_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 6
#       3     item_sim = np.corrcoef(pivot_df.T)
#       4     return item_sim
# ----> 6 item_sim_matrix = item_similarity_matrix(final_data)
#
# Cell In[21], line 2, in item_similarity_matrix(df)
#       1 def item_similarity_matrix(df):
# ----> 2     pivot_df = df.pivot(index='user_id', columns='restaurant_name', values='stars').fillna(0)
#       3     item_sim = np.corrcoef(pivot_df.T)
#       4     return item_sim
#
# File ~/anaconda3/envs/bigdata_ml/lib/python3.8/site-packages/pandas/core/frame.py:8414, in DataFrame.pivot(self, columns, index, values)
#    8409 @Substitution("")
#    8410 @Appender(_shared_docs["pivot"])
#    8411 def pivot(self, *, columns, index=lib.NoDefault, values=lib.NoDefault) -> DataFrame:
#    8412     from pandas.core.reshape.pivot import pivot
# -> 8414     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/anaconda3/envs/bigdata_ml/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:557, in pivot(data, columns, index, values)
#     553         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     554 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     555 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     556 # "Hashable"
# --> 557 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     558 result.index.names = [
#     559     name if name is not lib.NoDefault else None for name in result.index.names
#     560 ]
#     562 return result
#
# File ~/anaconda3/envs/bigdata_ml/lib/python3.8/site-packages/pandas/core/series.py:4313, in Series.unstack(self, level, fill_value)
#    4270 """
#    4271 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4272
#    (...)
#    4309 b    2    4
#    4310 """
#    4311 from pandas.core.reshape.reshape import unstack
# -> 4313 return unstack(self, level, fill_value)
#
# File ~/anaconda3/envs/bigdata_ml/lib/python3.8/site-packages/pandas/core/reshape/reshape.py:488, in unstack(obj, level, fill_value)
#     486 if is_1d_only_ea_dtype(obj.dtype):
#     487     return _unstack_extension_series(obj, level, fill_value)
# --> 488 unstacker = _Unstacker(
#     489     obj.index, level=level, constructor=obj._constructor_expanddim
#     490 )
#     491 return unstacker.get_result(
#     492     obj._values, value_columns=None, fill_value=fill_value
#     493 )
#
# File ~/anaconda3/envs/bigdata_ml/lib/python3.8/site-packages/pandas/core/reshape/reshape.py:136, in _Unstacker.__init__(self, index, level, constructor)
#     128 if num_cells > np.iinfo(np.int32).max:
#     129     warnings.warn(
#     130         f"The following operation may generate {num_cells} cells "
#     131         f"in the resulting pandas object.",
#     132         PerformanceWarning,
#     133         stacklevel=find_stack_level(),
#     134     )
# --> 136 self._make_selectors()
#
# File ~/anaconda3/envs/bigdata_ml/lib/python3.8/site-packages/pandas/core/reshape/reshape.py:188, in _Unstacker._make_selectors(self)
#     185 mask.put(selector, True)
#     187 if mask.sum() < len(self.index):
# --> 188     raise ValueError("Index contains duplicate entries, cannot reshape")
#     190 self.group_index = comp_index
#     191 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
def item_item_collaborative_filtering(user_id, item_sim_matrix, user_item_matrix, top_n=5):
    user_items = user_item_matrix.loc[user_id]
    non_rated_items = user_items[user_items.isnull()].index

    scores = item_sim_matrix[:, non_rated_items].T.dot(user_items)
    scores /= np.array(np.abs(item_sim_matrix[:, non_rated_items]).sum(axis=0)).reshape(-1, 1)

    top_items_idx = np.argsort(scores)[::-1][:top_n]
    top_items = non_rated_items[top_items_idx]
    return top_items

# Example usage: Recommend top 5 restaurants for user_id=1
user_id = 1
top_restaurants = item_item_collaborative_filtering(user_id, item_sim_matrix, df.pivot(index='user_id', columns='restaurant_id', values='rating'))
print(top_restaurants)

# %%
model_data['user_id']
# Out:
# 40         djp57omz9cccV1wI0_sqqA
# 41         djp57omz9cccV1wI0_sqqA
# 42         djp57omz9cccV1wI0_sqqA
# 43         djp57omz9cccV1wI0_sqqA
# 44         djp57omz9cccV1wI0_sqqA
#                     ...
# 5572066    Mc4C7fVY0sEcD-U5eOA2Og
# 5572085    huXqrSaGyNO1aZKiM55EUg
# 5572508    KEF5A094wOUdBG7SsS7qKg
# 5572754    zt9FNJMJNVt65Dl1GMuJqA
# 5572793    jrfAvTdjH0ykHEtJsqTRRA
# Name: user_id, Length: 1203530, dtype: object
